# %%
#Optimizer
#简单版本 

#batch_size  输入输出层数  
#神经元 
#激活函数  
#初始化值 
#代价函数——》交叉熵
#其它优化方式
#epoch 训练次数

#交叉熵代价函数

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets('MNIST_data',one_hot = True)
#批次大小 每次100张图片
batch_size = 100
#多少批次
n_batch = mnist.train.num_examples//batch_size

x = tf.placeholder(tf.float32,[None,784])#28*28=784
y = tf.placeholder(tf.float32,[None,10])#10 类
keep_prob = tf.placeholder(tf.float32)

#创建一个简单的神经网络 
#truncated_normal 初始化 ;增加隐藏层
W1 = tf.Variable(tf.truncated_normal([784,2000],stddev=0.1))
b1 = tf.Variable(tf.zeros([2000])+0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1,keep_prob)

W2 = tf.Variable(tf.truncated_normal([2000,2000],stddev=0.1))
b2 = tf.Variable(tf.zeros([2000]) + 0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2,keep_prob)

W3 = tf.Variable(tf.truncated_normal([2000,1000],stddev=0.1))
b3 = tf.Variable(tf.zeros([1000]) + 0.1)
L3 = tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)
L3_drop = tf.nn.dropout(L3,keep_prob)

W4 = tf.Variable(tf.truncated_normal([1000,10],stddev=0.1))
b4 = tf.Variable(tf.zeros([10]) + 0.1)


prediction = tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))

#loss = tf.reduce_mean(tf.square(y - prediction))

train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

init = tf.global_variables_initializer()

#结果存放在bool向量中，
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#最大的值在哪个位置

#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))#将bool 转化为 float  True 1.0 ;false 0.0 求平均值

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(31):#训练21次
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys,keep_prob:1.0})#控制多少神经元工作 1.0 全部工作 0.7 百分之七十工作，使用后收敛速度慢；误差变小（训练 测试）
            
        test_acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0})
        train_acc = sess.run(accuracy,feed_dict={x:mnist.train.images,y:mnist.train.labels,keep_prob:1.0})
        print("iter"+str(epoch)+"Testing Accuracy"+str(test_acc) + "Train Accuracy"+str(train_acc))

# %%
Extracting MNIST_data\train-images-idx3-ubyte.gz
Extracting MNIST_data\train-labels-idx1-ubyte.gz
Extracting MNIST_data\t10k-images-idx3-ubyte.gz
Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
iter0Testing Accuracy0.9482Train Accuracy0.9562
iter1Testing Accuracy0.9591Train Accuracy0.97401816
iter2Testing Accuracy0.9639Train Accuracy0.98252726
iter3Testing Accuracy0.9671Train Accuracy0.9863273
iter4Testing Accuracy0.969Train Accuracy0.98823637
iter5Testing Accuracy0.9684Train Accuracy0.98956364
iter6Testing Accuracy0.9686Train Accuracy0.99038184
iter7Testing Accuracy0.9702Train Accuracy0.99112725
iter8Testing Accuracy0.9708Train Accuracy0.9917091
iter9Testing Accuracy0.9705Train Accuracy0.99216366
iter10Testing Accuracy0.9716Train Accuracy0.9926
iter11Testing Accuracy0.9718Train Accuracy0.99292725
iter12Testing Accuracy0.972Train Accuracy0.9933091
iter13Testing Accuracy0.9723Train Accuracy0.99358183
iter14Testing Accuracy0.9719Train Accuracy0.9938
iter15Testing Accuracy0.9728Train Accuracy0.994
iter16Testing Accuracy0.972Train Accuracy0.99423635
iter17Testing Accuracy0.973Train Accuracy0.99438184
iter18Testing Accuracy0.9724Train Accuracy0.9944909
iter19Testing Accuracy0.9727Train Accuracy0.9946182
iter20Testing Accuracy0.9731Train Accuracy0.9948364
iter21Testing Accuracy0.9736Train Accuracy0.9949273
iter22Testing Accuracy0.9738Train Accuracy0.995
iter23Testing Accuracy0.9741Train Accuracy0.99505454
iter24Testing Accuracy0.9741Train Accuracy0.99514544
iter25Testing Accuracy0.974Train Accuracy0.99521816
iter26Testing Accuracy0.9738Train Accuracy0.9953091
iter27Testing Accuracy0.9741Train Accuracy0.9953273
iter28Testing Accuracy0.9739Train Accuracy0.99536365
iter29Testing Accuracy0.9741Train Accuracy0.9954182
iter30Testing Accuracy0.9739Train Accuracy0.9954727
